# %%
import numpy as np
from matplotlib import pyplot as plt
x=[]
for i in range(50):
    x1=np.random.poisson(lam=2,size=10)
    e1=np.mean(x1)
    x.append(e1)

# %%
plt.figure()
plt.hist(x,bins=10,alpha=1)  #直方图关键操作 500还算不错
plt.grid(alpha=0.5,linestyle='-.') #网格线
plt.show()
